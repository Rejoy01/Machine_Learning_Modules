# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris_df=pd.DataFrame(iris.data,columns=iris.feature_names)
iris_df['species']= iris.target
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# X and y values
X = iris_df.drop(['species'],axis = 1)
y = iris_df['species']

# %%
from numpy import size


X_train,X_test,y_train,y_test = train_test_split(X,y,test_size =0.3,random_state=17)

print(f"The dimensions of X_train is {X_train.shape}")
print(f"The dimensions of X_test is {X_test.shape}")
# Out:
# The dimensions of X_train is (105, 4)
# The dimensions of X_test is (45, 4)

# %%
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
score = dt_classifier.score(X_train, y_train)
print(" R - squared train",score)


y_pred = dt_classifier.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
#  R - squared train 1.0
# MSE : 0.0
# RMSE : 0.0

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_classifier,filled=True)
plt.show()

# %%
dt_classifier = DecisionTreeClassifier(criterion= "entropy",max_depth=5)
dt_classifier.fit(X_train, y_train)

score = dt_classifier.score(X_train, y_train)
print(" R - squared train",score)

score = dt_classifier.score(X_test, y_test)
print(" R - squared test",score)

y_pred = dt_classifier.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
#  R - squared train 0.9809523809523809
#  R - squared test 0.9777777777777777
# MSE : 0.022222222222222223
# RMSE : 0.14907119849998599

# %%
from sklearn.ensemble import AdaBoostRegressor
clf = AdaBoostRegressor()

clf.fit(X_train,y_train)
score = clf.score(X_train, y_train)
print(f" Train accuracy for {clf.__class__.__name__} is {score}")
score = clf.score(X_test, y_test)
print(f" Test accuracy for {clf.__class__.__name__} is {score}")
print("============================")
# Out:
#  Train accuracy for AdaBoostRegressor is 0.9963689339716754
#  Test accuracy for AdaBoostRegressor is 0.9676198979911474
# ============================

# %%
from sklearn.ensemble import GradientBoostingRegressor
clf = GradientBoostingRegressor()

clf.fit(X_train,y_train)
score = clf.score(X_train, y_train)
print(f" Train accuracy for {clf.__class__.__name__} is {score}")
score = clf.score(X_test, y_test)
print(f" Test accuracy for {clf.__class__.__name__} is {score}")
print("============================")
# Out:
#  Train accuracy for GradientBoostingRegressor is 0.9996712942836254
#  Test accuracy for GradientBoostingRegressor is 0.9606770942231231
# ============================
